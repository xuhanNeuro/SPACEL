# %% [markdown]
# # SPACEL workflow (1/3): Deconvolution by Spoint on mouse brain ST dataset

# %% [markdown]
# July 2023

# %% [markdown]
# Dataset: 75 ST slices of mouse brain ([here](https://zenodo.org/record/8167488))

# %%
# import os
# os.environ['PYTORCH_DEVICE'] = 'cpu'
# os.environ['PYTORCH_MPS_ENABLE'] = '0'
# import torch
# torch.device('cpu')  # Set default device to CPU



import pandas as pd
import scanpy as sc
import anndata
import os
from tqdm import tqdm 
import scanpy as sc
import numpy as np
import sys

# %% [markdown]
# ## Load spatial transcriptomics data

# %%
import sys
sys.path.append('/Users/u0096223/Documents/GitHub/PVLabTime/Merscope')
data_dir = '/Users/u0096223/Baidu/Science/Data PVDH/NovaST_data/NovaST_P5_LP_CTB_202503/deep_result'
# anndata_filename = os.path.join(data_dir,'15-11-24_23-22_P5_mouse_brain_CBD_panel_Cells_annotated.h5ad')
# anndata_filename = os.path.join(data_dir,'Spoint_result_mouse_brain_st.h5ad')

### case 1: RetroSeq_xu data, P5 thalamocortical 
sc_files ='/Users/u0096223/Documents/Transcriptomics/P5_thalamocortical_240715/P5_thalamocortical_Xcount.h5ad' # retroSeq xu
fig_root = os.path.join(data_dir,'Figures_spatial_mapping_retroSeq_xu')

### case 2: P7 thalamus data, Giudice 2024
sc_files ='/Users/u0096223/Documents/data/public data/Lo Giudice 2024 thalamus/PostNat_P7_control_raw_count_annotated.h5ad' # retroSeq xu
fig_root = os.path.join(data_dir,'Figures_spatial_mapping_P7_thalamus')

# ### case 3: P5 Allen V1 data
# sc_files ='/Users/u0096223/Baidu/Science/Data PVDH/Public data transcriptiomic/V1_P5_Allen_snRNA/Reference_V1_P5_CTX_Allen_snRNA_processed.h5ad' # retroSeq xu
# fig_root = os.path.join(data_dir,'Figures_spatial_mapping_P5_Allen_V1')


### spatial data to be mapped ###
spatial_file =os.path.join(data_dir,'adata_thal_all_50.h5ad')

pn_trained_model= os.path.join(fig_root,'SPOINT_trained_model.h5')

# %% [markdown]
# The input data are anndata objects stored raw counts for scRNA-seq and ST. The scRNA-seq anndata must have cell type annotation in ``.obs``.

# %%
adata = sc.read(spatial_file)
scadata = sc.read_h5ad(sc_files)

# %%
scadata.obs
# Out:
#                                                 Unnamed: 0  umi.counts  \
# AAACCCAAGAACGCGT-L8TX_210506_01_D07-1157582451      142296       46387
# AAACCCAAGCGACTTT-L8TX_210506_01_D07-1157582451      142297       43831
# AAACCCAAGGCAGCTA-L8TX_210506_01_D07-1157582451      142298       31535
# AAACCCACACACACGC-L8TX_210506_01_D07-1157582451      142299       35825
# AAACCCACATCTCCCA-L8TX_210506_01_D07-1157582451      142300       42134
# ...                                                    ...         ...
# TTTGTTGAGCAGAAAG-L8TX_210506_01_H07-1157582454      155647       24767
# TTTGTTGCATAGCACT-L8TX_210506_01_H07-1157582454      155648       28764
# TTTGTTGGTCATAAAG-L8TX_210506_01_H07-1157582454      155649       10077
# TTTGTTGGTGCAGGAT-L8TX_210506_01_H07-1157582454      155650        3541
# TTTGTTGTCGATAACC-L8TX_210506_01_H07-1157582454      155651       11748
#
#                                                 gene.counts.0  \
# AAACCCACATCTCCCA-L8TX_210506_01_D07-1157582451  RFP-positive, Hoechst-positive
# ...                                                                        ...
# TTTGTTGAGCAGAAAG-L8TX_210506_01_H07-1157582454                         No FACS
# TTTGTTGCATAGCACT-L8TX_210506_01_H07-1157582454                         No FACS
# TTTGTTGGTCATAAAG-L8TX_210506_01_H07-1157582454                         No FACS
# TTTGTTGGTGCAGGAT-L8TX_210506_01_H07-1157582454                         No FACS
# TTTGTTGTCGATAACC-L8TX_210506_01_H07-1157582454                         No FACS
#
#                                                 roi load_name  \
# AAACCCAAGAACGCGT-L8TX_210506_01_D07-1157582451  VIS   634_A03
# AAACCCAAGCGACTTT-L8TX_210506_01_D07-1157582451  VIS   634_A03
# AAACCCAAGGCAGCTA-L8TX_210506_01_D07-1157582451  VIS   634_A03
# AAACCCACACACACGC-L8TX_210506_01_D07-1157582451  VIS   634_A03
# AAACCCACATCTCCCA-L8TX_210506_01_D07-1157582451  VIS   634_A03
# ...                                             ...       ...
# TTTGTTGAGCAGAAAG-L8TX_210506_01_H07-1157582454  VIS   634_B03
# TTTGTTGCATAGCACT-L8TX_210506_01_H07-1157582454  VIS   634_B03
# TTTGTTGGTCATAAAG-L8TX_210506_01_H07-1157582454  VIS   634_B03
# TTTGTTGGTGCAGGAT-L8TX_210506_01_H07-1157582454  VIS   634_B03
# TTTGTTGTCGATAACC-L8TX_210506_01_H07-1157582454  VIS   634_B03
#
#                                                       library_prep  ...  \
# AAACCCAAGAACGCGT-L8TX_210506_01_D07-1157582451  L8TX_210506_01_D07  ...
# AAACCCAAGCGACTTT-L8TX_210506_01_D07-1157582451  L8TX_210506_01_D07  ...
# AAACCCAAGGCAGCTA-L8TX_210506_01_D07-1157582451  L8TX_210506_01_D07  ...
# AAACCCACACACACGC-L8TX_210506_01_D07-1157582451  L8TX_210506_01_D07  ...
# AAACCCACATCTCCCA-L8TX_210506_01_D07-1157582451  L8TX_210506_01_D07  ...
# ...                                                            ...  ...
# TTTGTTGAGCAGAAAG-L8TX_210506_01_H07-1157582454  L8TX_210506_01_H07  ...
# TTTGTTGCATAGCACT-L8TX_210506_01_H07-1157582454  L8TX_210506_01_H07  ...
# TTTGTTGGTCATAAAG-L8TX_210506_01_H07-1157582454  L8TX_210506_01_H07  ...
# TTTGTTGGTGCAGGAT-L8TX_210506_01_H07-1157582454  L8TX_210506_01_H07  ...
# TTTGTTGTCGATAACC-L8TX_210506_01_H07-1157582454  L8TX_210506_01_H07  ...
#
#                                                 log1p_total_counts_mt  \
# AAACCCAAGAACGCGT-L8TX_210506_01_D07-1157582451               4.753590
# AAACCCAAGCGACTTT-L8TX_210506_01_D07-1157582451               4.820282
# AAACCCAAGGCAGCTA-L8TX_210506_01_D07-1157582451               4.836282
# AAACCCACACACACGC-L8TX_210506_01_D07-1157582451               4.804021
# AAACCCACATCTCCCA-L8TX_210506_01_D07-1157582451               4.875197
# ...                                                               ...
# TTTGTTGAGCAGAAAG-L8TX_210506_01_H07-1157582454               4.804021
# TTTGTTGCATAGCACT-L8TX_210506_01_H07-1157582454               4.779123
# ...                                                         ...
# TTTGTTGAGCAGAAAG-L8TX_210506_01_H07-1157582454         1.979606
# TTTGTTGCATAGCACT-L8TX_210506_01_H07-1157582454         1.690475
# TTTGTTGGTCATAAAG-L8TX_210506_01_H07-1157582454         2.661938
# TTTGTTGGTGCAGGAT-L8TX_210506_01_H07-1157582454         3.042562
# TTTGTTGTCGATAACC-L8TX_210506_01_H07-1157582454         2.052630
#
#                                                total_counts_hb  \
# AAACCCAAGAACGCGT-L8TX_210506_01_D07-1157582451             0.0
# AAACCCAAGCGACTTT-L8TX_210506_01_D07-1157582451             9.0
# AAACCCAAGGCAGCTA-L8TX_210506_01_D07-1157582451             6.0
# AAACCCACACACACGC-L8TX_210506_01_D07-1157582451             6.0
# AAACCCACATCTCCCA-L8TX_210506_01_D07-1157582451            11.0
# ...                                                        ...
# TTTGTTGAGCAGAAAG-L8TX_210506_01_H07-1157582454            11.0
# TTTGTTGCATAGCACT-L8TX_210506_01_H07-1157582454            12.0
# TTTGTTGGTCATAAAG-L8TX_210506_01_H07-1157582454             0.0
# TTTGTTGGTGCAGGAT-L8TX_210506_01_H07-1157582454             0.0
# TTTGTTGTCGATAACC-L8TX_210506_01_H07-1157582454             0.0
#
#                                                 log1p_total_counts_hb  \
# AAACCCAAGAACGCGT-L8TX_210506_01_D07-1157582451               0.000000
# AAACCCAAGCGACTTT-L8TX_210506_01_D07-1157582451               2.302585
# AAACCCAAGGCAGCTA-L8TX_210506_01_D07-1157582451               1.945910
# AAACCCACACACACGC-L8TX_210506_01_D07-1157582451               1.945910
# AAACCCACATCTCCCA-L8TX_210506_01_D07-1157582451               2.484907
# ...                                                               ...
# TTTGTTGAGCAGAAAG-L8TX_210506_01_H07-1157582454               2.484907
# TTTGTTGCATAGCACT-L8TX_210506_01_H07-1157582454               2.564949
# TTTGTTGGTCATAAAG-L8TX_210506_01_H07-1157582454               0.000000
# TTTGTTGGTGCAGGAT-L8TX_210506_01_H07-1157582454               0.000000
# TTTGTTGTCGATAACC-L8TX_210506_01_H07-1157582454               0.000000
#
#                                                 pct_counts_hb  n_genes  leiden
# AAACCCAAGAACGCGT-L8TX_210506_01_D07-1157582451       0.000000     7916       7
# AAACCCAAGCGACTTT-L8TX_210506_01_D07-1157582451       0.020925     7821      20
# AAACCCAAGGCAGCTA-L8TX_210506_01_D07-1157582451       0.014952     6714      17
# AAACCCACACACACGC-L8TX_210506_01_D07-1157582451       0.015799     6991       0
# AAACCCACATCTCCCA-L8TX_210506_01_D07-1157582451       0.027102     7448      20
# ...                                                       ...      ...     ...
# TTTGTTGAGCAGAAAG-L8TX_210506_01_H07-1157582454       0.029912     6124       3
# TTTGTTGCATAGCACT-L8TX_210506_01_H07-1157582454       0.029657     6702       9
# TTTGTTGGTCATAAAG-L8TX_210506_01_H07-1157582454       0.000000     3617      16
# TTTGTTGGTGCAGGAT-L8TX_210506_01_H07-1157582454       0.000000     2091       9
# TTTGTTGTCGATAACC-L8TX_210506_01_H07-1157582454       0.000000     4144      15
#
# [13356 rows x 43 columns]

# %%
scadata.var_names_make_unique()
scadata.obs_names_make_unique()

# %% [markdown]
# ## Initialize and train the Spoint model

# %% [markdown]
# In this step, we initialize the Spoint model using anndata objects for scRNA-seq and ST as input. The``celltype_key`` parameter represents the column name of the cell type annotation in the .obs attribute of the scRNA-seq anndata object. The ``sm_size`` parameter controls the number of simulated spots, and it is important to have a sufficient ``sm_size`` for accurate prediction. However, it should be noted that increasing the ``sm_size`` will also increase the simulation and training time. In general, we recommend setting ``sm_size`` to a value greater than 100,000.

# %%
import SPACEL
from SPACEL.setting import set_environ_seed
set_environ_seed()
from SPACEL import Spoint
# Out:
# Setting environment seed: 42
# Global seed set to 0

# %%
# spoint_model = Spoint.init_model(scadata,adata,celltype_key='leiden',sm_size=500000,use_gpu=False,n_threads=2) #30min
spoint_model = Spoint.init_model(scadata,adata,celltype_key='cluster_label',sm_size=500000,use_gpu=False) #30min

spoint_model.train(max_steps=5000, batch_size=1024) # 11h!!!
# Out:
# Setting global seed: 42
# /opt/anaconda3/envs/SPACEL/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:196: UserWarning: Some cells have zero counts
#   warn(UserWarning('Some cells have zero counts'))
# ### Finding marker genes...
# ### Filter cluster contain only one sample: ['662_Vip Gaba_12']
# cluster_label
# 5269_OPC NN_1           99
# 5225_Astro-TE NN_3      96
# 5311_Endo NN_1          93
# 5312_Microglia NN_1     84
# Glioblast SVZ           84
#                         ..
# IMN IT Upper Layer      35
# 367_L5 ET CTX Glut_3    34
# 371_L5 ET CTX Glut_4    28
# 779_Sst Gaba_4          27
# Glioblast               25
# Name: count, Length: 61, dtype: int64
# ### Used gene numbers: 412
# ### Initializing sample probability
# ### Genetating simulated spatial data using scRNA data with mode: unbalance
# ### Genetating simulated spatial data using scRNA data with mode: sqrt
# ### Genetating simulated spatial data using scRNA data with mode: balance
# Global seed set to 0
# Global seed set to 0
# Global seed set to 0
# Global seed set to 0
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /opt/anaconda3/envs/SPACEL/lib/python3.8/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Epoch 100/100: 100%|███████| 100/100 [24:31<00:00, 14.76s/it, loss=393, v_num=1]
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Epoch 100/100: 100%|███████| 100/100 [24:31<00:00, 14.72s/it, loss=393, v_num=1]
# Step 5000: Test inference loss=-0.674: 100%|█| 5000/5000 [11:40:22<00:00,  8.40s

# %%
# save the model
import torch
torch.save(spoint_model.model.state_dict(), pn_trained_model)

# %%
# to be tested, load spoint model
spoint_model.model.load_state_dict(torch.load(pn_trained_model))

# %% [markdown]
# Then, we utilize the trained model to predict the cell type composition of each spot in the spatial transcriptomics data. This prediction will generate a DataFrame object, where each row corresponds to a spot in the spatial transcriptomics data, each column represents a cell type from the single-cell RNA-seq data, and each entry indicates the proportion of a particular cell type in a spot. Additionally, we can obtain the anndata object of the spatial transcriptomics data with the deconvolution results embedded in the .obs attribute.

# %%
# run prediction 
pre = spoint_model.deconv_spatial()
st_ad = spoint_model.st_ad

# %%
st_ad.write(os.path.join(fig_root,'Spoint_result_mouse_brain_st.h5ad'))

# %%
import pandas as pd

# Save to CSV
pre.to_csv(os.path.join(fig_root,'spoint_model_deconv_spatial.csv'), index=False)

# %% [markdown]
# ## Visualization results

# %% [markdown]
# As a demonstration, we plotted the predicted compositions of cell types on a slice, where the cell types are selected as the top 20 with the highest proportion within each spot.

# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
matplotlib.rcParams['font.serif'] = ['Arial']
sc.settings.set_figure_params(dpi=50,dpi_save=300,facecolor='white',fontsize=10,vector_friendly=True,figsize=(3,3))
sc.settings.verbosity = 3

# %%
st_ad.obs
# Out:
#                     Custom Cells groups  \
# 4176488300003100058         Unclustered
# 4176488300003100061         Unclustered
# 4176488300003100074         Unclustered
# 4176488300003100075         Unclustered
# 4176488300003100081         Unclustered
# ...                                 ...
# 4176488700197100074         Unclustered
# 4176488700197100120         Unclustered
# 4176488700197100126         Unclustered
# 4176488700197100136         Unclustered
# 4176488700197100143         Unclustered
#
#                                                            Datasets  \
# 4176488300003100058  202411071245_Xu-P5-ms-brain_VMSC08602_region_0
# 4176488300003100061  202411071245_Xu-P5-ms-brain_VMSC08602_region_0
# 4176488300003100074  202411071245_Xu-P5-ms-brain_VMSC08602_region_0
# 4176488300003100075  202411071245_Xu-P5-ms-brain_VMSC08602_region_0
# 4176488300003100081  202411071245_Xu-P5-ms-brain_VMSC08602_region_0
# ...                                                             ...
# 4176488700197100074  202411071245_Xu-P5-ms-brain_VMSC08602_region_1
# 4176488700197100120  202411071245_Xu-P5-ms-brain_VMSC08602_region_1
# 4176488700197100126  202411071245_Xu-P5-ms-brain_VMSC08602_region_1
# 4176488700197100136  202411071245_Xu-P5-ms-brain_VMSC08602_region_1
# 4176488700197100143  202411071245_Xu-P5-ms-brain_VMSC08602_region_1
#
#                           volume     center_x      center_y  n_genes batch  \
# 4176488300003100058   679.729797  1864.685227    370.966180        1  real
# 4176488300003100061   421.822998  1844.958006    372.673463        1  real
# 4176488300003100074   875.621033  2026.338017    380.136557        1  real
# 4176488300003100075  2463.850586  1882.568016    386.052514        1  real
# 4176488300003100081  3240.593506  1721.412778    402.387977        1  real
# ...                          ...          ...           ...      ...   ...
# 4176488700197100074  2639.967285  5930.508174  12743.723030        1  real
# 4176488700197100120  2153.245361  5901.349850  12811.844244        1  real
# 4176488700197100126  1115.132446  5775.783258  12817.580085        1  real
# 4176488700197100136  1696.354370  5652.479659  12830.909431        1  real
# 4176488700197100143  1095.484497  5781.313224  12843.759010        1  real
#
#                      0641 AD Serpinb7 Glut_1  \
# 4176488300003100058                 0.113572
# 4176488300003100061                 0.121459
# 4176488300003100074                 0.171256
# 4176488300003100075                 0.120751
# 4176488300003100081                 0.105762
# ...                                      ...
# 4176488700197100074                 0.120266
# 4176488700197100120                 0.130050
# 4176488700197100126                 0.149157
# 4176488700197100136                 0.171256
# 4176488700197100143                 0.171256
#
#                      0650 CM-IAD-CL-PCN Sema5b Glut_2  \
# 4176488300003100058                          0.055957
# 4176488300003100061                          0.044972
# 4176488300003100074                          0.058806
# 4176488300003100075                          0.064514
# 4176488300003100081                          0.056548
# ...                                               ...
# 4176488700197100074                          0.064146
# 4176488700197100120                          0.077804
# 4176488700197100126                          0.070730
# 4176488700197100136                          0.058806
# 4176488700197100143                          0.058806
#
#                      0659 TH Prkcd Grin2c Glut_6  ...  \
# 4176488300003100058                     0.150838  ...
# 4176488300003100061                     0.207865  ...
# 4176488300003100074                     0.132689  ...
# ...                             ...
# 4176488700197100074             0.0
# 4176488700197100120             0.0
# 4176488700197100126             0.0
# 4176488700197100136             0.0
# 4176488700197100143             0.0
#
# [248377 rows x 287 columns]

# %%
import sys
sys.path.append('/Users/u0096223/Documents/GitHub/PVLabTime/Merscope')
from MerscopeBrainAnalysis import MerscopeBrainAnalysis

data_dir = '/Users/u0096223/Baidu/Science/Data PVDH/MERSCOPE data/P5_mouse_brain_CBD_panel/Cells'
fig_root = os.path.join(data_dir,'Figures_spatial_mapping_retroSeq_xu')

# sc_files ='/Users/u0096223/Documents/Transcriptomics/P5_thalamocortical_240715/P5_thalamocortical_Xcount.h5ad'
spatial_file =os.path.join(fig_root,'Spoint_result_mouse_brain_st.h5ad')

st_ad = anndata.read_h5ad(spatial_file)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 3
#       1 import sys
#       2 sys.path.append('/Users/u0096223/Documents/GitHub/PVLabTime/Merscope')
# ----> 3 from MerscopeBrainAnalysis import MerscopeBrainAnalysis
#       5 data_dir = '/Users/u0096223/Baidu/Science/Data PVDH/MERSCOPE data/P5_mouse_brain_CBD_panel/Cells'
#       6 anndata_filename = os.path.join(data_dir,'Spoint_result_mouse_brain_st.h5ad.h5ad')
#
# File ~/Documents/GitHub/PVLabTime/Merscope/MerscopeBrainAnalysis.py:13
#      11 import seaborn as sns
#      12 from typing import Optional, List, Dict, Tuple, Union
# ---> 13 import cellphonedb
#      14 import harmonypy
#      15 import gseapy as gp
#
# ModuleNotFoundError: No module named 'cellphonedb'

# %%
# st_ad = st_ad[st_ad.obs.slice==37]
# celltype = st_ad.obs.loc[:,pre.columns].max(0)
st_ad = st_ad[st_ad.obs.Datasets.str.contains('region_0')]
celltype = st_ad.obs.loc[:,pre.columns].max(0)

# %%
print(st_ad.obs.columns.tolist())
# Out:
# ['Custom Cells groups', 'Datasets', 'volume', 'center_x', 'center_y', 'n_genes', 'batch', '0641 AD Serpinb7 Glut_1', '0650 CM-IAD-CL-PCN Sema5b Glut_2', '0659 TH Prkcd Grin2c Glut_6', '0670 RE-Xi Nox4 Glut_3', '0646 PVT-PT Ntrk1 Glut_4', '0668 RE-Xi Nox4 Glut_1', '0661 TH Prkcd Grin2c Glut_8', '0653 CM-IAD-CL-PCN Sema5b Glut_5', '0689 IF-RL-CLI-PAG Foxa1 Glut_5', '0974 PGRN-PARN-MDRN Hoxb5 Glut_2', '0658 TH Prkcd Grin2c Glut_5', '0652 CM-IAD-CL-PCN Sema5b Glut_4', '0675 PF Fzd5 Glut_2', '0673 MG-POL-SGN Nts Glut_2', '0724 SPA-SPFm-SPFp-POL-PIL-PoT Sp9 Glut_7', '0674 PF Fzd5 Glut_1', '0642 AV Col27a1 Glut_1', '0880 SNc-VTA-RAmb Foxa1 Dopa_1', '0721 SPA-SPFm-SPFp-POL-PIL-PoT Sp9 Glut_4', '0702 APN C1ql2 Glut_1', '0790 ND-INC Foxd2 Glut_1', '0530 SI-MA-LPO-LHA Skor1 Glut_1', '0518 MS-SF Bsx Glut_1', '0717 PRC-PAG Tcf7l2 Irx2 Glut_5', '0651 CM-IAD-CL-PCN Sema5b Glut_3', '0671 R
Glut_1', '0840 LGv-SPFp-SPFm Nkx2-2 Tcf7l2 Gaba_7', '0143 OB Meis2 Thsd7b Gaba_1', '0672 MG-POL-SGN Nts Glut_1', '0831 PRT Tcf7l2 Gaba_3', '0126 L5 NP CTX Glut_5', '0698 CUN Evx2 Lhx2 Glut_2', '0691 PAG-SC Neurod2 Meis2 Glut_2', '0660 TH Prkcd Grin2c Glut_7', '0962 NTS Phox2b Glut_4', '1160 Astro-NT NN_2', '0648 PVT-PT Ntrk1 Glut_6', '0125 L5 NP CTX Glut_4', '1072 DTN-LDT-IPN Otp Pax3 Gaba_4', '1074 NLL Gata3 Gly-Gaba_1', '1085 PRP Otp Gly-Gaba_3', '0610 PH Pitx2 Glut_1', '0749 PAG Pou4f2 Glut_5', '0679 PRC-PAG Pax6 Glut_4', '0771 IC Tfap2d Maf Glut_2', '0500 LGv-ZI Otx2 Gaba_5', '0927 PCG-PRNr Vsx2 Nkx6-1 Glut_3', '0504 GPi Tbr1 Cngb3 Gaba-Glut_1', '0736 PAG Pou4f1 Bnc2 Glut_2', '0406 MPO-ADP Lhx8 Gaba_5', '0715 PRC-PAG Tcf7l2 Irx2 Glut_3', '0943 PB-NTS Phox2b Ebf3 Lmx1b Glut_1', '0726 SPA-SPFm-SPFp-POL-PIL-PoT Sp9 Glut_9', '0532 SI-MA-LPO-LHA Skor1 Glut_3', '0956 PRP-NI-PRNc-GRN Otp Glut_2', '0552 DMH Hmx2 Glut_1', '0558 ARH-PVp Tbx3 Glut_5', '0561 DMH-LHA Vgll2 Glut_3', '0566 VMH Nr5a1 Glut_1', '0960 NTS Phox2b Glut_2', '0123 L5 NP CTX Glut_2', '0850 SCm-PAG Cdh23 Gaba_3', '0961 NTS Phox2b Glut_3', '1044 CS-PRNr-PCG Tmem163 Otp Gaba_1', '0499 LGv-ZI  ...

# %%
sc.pl.embedding(st_ad,color=celltype.sort_values(ascending=False)[:20].index,basis='spatial',ncols=5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sc.pl.embedding(st_ad,color=celltype.sort_values(ascending=False)[:20].index,basis='spatial',ncols=5)
#
# File /opt/anaconda3/envs/SPACEL/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:135, in embedding(adata, basis, color, gene_symbols, use_raw, sort_order, edges, edges_width, edges_color, neighbors_key, arrows, arrows_kwds, groups, components, dimensions, layer, projection, scale_factor, color_map, cmap, palette, na_color, na_in_legend, size, frameon, legend_fontsize, legend_fontweight, legend_loc, legend_fontoutline, colorbar_loc, vmax, vmin, vcenter, norm, add_outline, outline_width, outline_color, ncols, hspace, wspace, title, show, save, ax, return_fig, **kwargs)
#     132 check_projection(projection)
#     133 sanitize_anndata(adata)
# --> 135 basis_values = _get_basis(adata, basis)
#     136 dimensions = _components_to_dimensions(
#     137     components, dimensions, projection=projection, total_dims=basis_values.shape[1]
#     138 )
#     139 args_3d = dict(projection='3d') if projection == '3d' else {}
#
# File /opt/anaconda3/envs/SPACEL/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:1148, in _get_basis(adata, basis)
#    1146     return adata.obsm[f"X_{basis}"]
#    1147 else:
# -> 1148     raise KeyError(f"Could not find '{basis}' or 'X_{basis}' in .obsm")
#
# KeyError: "Could not find 'spatial' or 'X_spatial' in .obsm"
